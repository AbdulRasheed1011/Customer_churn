# %%
import yaml

# %%
path = 'configs/config.yaml'

# %%
with open(path, 'r', encoding = 'utf-8') as f:
    config = yaml.safe_load(f)
    print(config)
# Out:
# {'paths': {'raw_data': 'data/raw/telecom.csv'}, 'schema': {'target_column': 'churn'}, 'split': {'test_size': 0.2}}
